# %%
N = 8

possible = set()

for i in range(1,N+1):
    for j in range(i+3,N+1,2):
        possible.add((i,j))

print(possible)
# Out:
# {(2, 7), (4, 7), (1, 4), (3, 8), (1, 8), (1, 6), (3, 6), (2, 5), (5, 8)}

# %%
import math
math.average([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-9082271812c6> in <module>()
#       1 import math
# ----> 2 math.average([1,2,3])
#
# AttributeError: module 'math' has no attribute 'average'

# %%
arr = [100] + [-1]*100
print(arr[0:3])

for x in range (-10,1001):
    print(x/10, sum([abs(x/10-a) for a in arr[0:10]]))
# Out:
# [100, -1, -1]
# -1.0 101.0
# -0.9 101.79999999999995
# -0.8 102.60000000000002
# -0.7 103.39999999999998
# -0.6 104.20000000000005
# -0.5 105.0
# -0.4 105.79999999999995
# -0.3 106.60000000000002
# -0.2 107.39999999999998
# -0.1 108.20000000000005
# 0.0 109.0
# 0.1 109.79999999999995
# 0.2 110.60000000000002
# 0.3 111.39999999999998
# 0.4 112.20000000000005
# 0.5 113.0
# 0.6 113.79999999999995
# 0.7 114.60000000000002
# 0.8 115.39999999999998
# 0.9 116.20000000000005
# 1.0 117.0
# 1.1 117.79999999999995
# 1.2 118.60000000000002
# 1.3 119.39999999999998
# 1.4 120.20000000000005
# 1.5 121.0
# 1.6 121.79999999999995
# 1.7 122.60000000000002
# 1.8 123.39999999999998
# 1.9 124.20000000000005
# 2.0 125.0
# 2.1 125.79999999999995
# 2.2 126.60000000000002
# 2.3 127.39999999999998
# 2.4 128.20000000000005
# 2.5 129.0
# 2.6 129.79999999999995
# 2.7 130.60000000000002
# 2.8 131.39999999999998
# 2.9 132.20000000000005
# 3.0 133.0
# 3.1 133.79999999999995
# 3.2 134.6
# 3.3 135.4
# ...
